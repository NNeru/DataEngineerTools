# %% [markdown]
# #  Consignes
#
# ## Description
#
# Ouvrir le fichier ks-projects-201801.csv, il recense environ 100 000 projets KickStarter. Intégrer les données directement avec L'API Python dans une base de données Mongo.
#
# Il conviendra de bien spécifier manuellement l'ID du document. Pensez aussi à bien formatter le type des données pour profiter des méthodes implémentées par Mongo. L'ensemble de données n'est pas forcément nécessaire, c'est à vous de créer votre modèle de données.
#
# ## Questions
#
# - 1) Récupérer les 5 projets ayant reçu le plus de promesse de dons.
# - 2) Compter le nombre de projets ayant atteint leur but.
# - 3) Compter le nombre de projets pour chaque catégorie.
# - 4) Compter le nombre de projets français ayant été instanciés avant 2016.
# - 5) Récupérer les projets américains ayant demandé plus de 200 000 dollars.
# - 6) Compter le nombre de projet ayant "Sport" dans leur nom

# %%
import pandas as pd
import pymongo

# %%
client = pymongo.MongoClient("mongo")
database = client['exercices']
collection = database['kickstarter']

# %%
df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv")
df_ks.head()
# Out:
# /root/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (6,8,10,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            ID                                               name  \
# 0   872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1  1326492673                                    Ohceola jewelry
# 2  1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3   156812982  SketchPlanner: Create and Plan- all in one bea...
# 4  1835968190    Proven sales with custom motorcycle accessories
#
#          category main_category currency    deadline   goal  \
# 0            Rock         Music      USD  2011-09-16   2000
# 1         Fashion       Fashion      USD  2012-08-22  18000
# 2  Tabletop Games         Games      USD  2016-07-19   2000
# 3       Art Books    Publishing      USD  2017-09-27  13000
# 4       Sculpture           Art      CAD  2016-02-24   5000
#
#               launched pledged       state backers country usd pledged  \
# 0  2011-08-17 06:31:31    1145    canceled      24      US        1145
# 1  2012-07-23 20:46:48    1851      failed      28      US        1851
# 2  2016-07-01 21:55:54    7534  successful     254      US        3796
# 3  2017-08-28 15:47:02   16298  successful     367      US        2670
# 4  2016-01-25 17:37:10       1      failed       1      CA    0.708148
#
#    usd_pledged_real
# 0       1145.000000
# 1       1851.000000
# 2       7534.000000
# 3      16298.000000
# 4          0.738225

# %% [markdown]
# Ce warning intervient lorsque pandas n'arrive pas à inférer le type de données. Il est sympa il précise les colones 6,8,10,12.

# %%
df_ks.columns[[6,8,10,12]]
# Out:
# Index(['goal', 'pledged', 'backers', 'usd pledged'], dtype='object')

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Netoyer les données

# %%
df_ks['launched'] = pd.to_datetime(df_ks['launched'],errors='coerce')
df_ks['pledged'] = pd.to_numeric(df_ks['pledged'])
df_ks['goal'] = pd.to_numeric(df_ks['goal'])
df_ks = df_ks.dropna(subset=['launched'])

# %%
df_ks = df_ks.rename(columns={"ID": "_id"})

# %%
df_ks.dtypes
# Out:
# _id                          int64
# name                        object
# category                    object
# main_category               object
# currency                    object
# deadline                    object
# goal                       float64
# launched            datetime64[ns]
# pledged                    float64
# state                       object
# backers                     object
# country                     object
# usd pledged                 object
# usd_pledged_real           float64
# dtype: object

# %%
df_ks.country.unique()
# Out:
# array(['US', 'CA', 'HK', 'BE', 'GB', 'NO', 'NL', 'N,0"', 'AU', 'CH', 'SE',
#        'AT', 'NZ', 'MX', 'FR', 'DK', 'IT', 'ES', 'DE', 'IE', 'SG', 'LU',
#        'JP'], dtype=object)

# %% [markdown]
# ### Importer les données

# %%
documents = df_ks.to_dict(orient = 'records')

# %%
collection.insert_many(documents)

# %%
collection.find_one()
# Out:
# {'_id': 872782264,
#  'name': 'Scott Cooper\'s Solo CD "A Leg Trick" (Canceled)',
#  'category': 'Rock',
#  'main_category': 'Music',
#  'currency': 'USD',
#  'deadline': '2011-09-16',
#  'goal': 2000.0,
#  'launched': datetime.datetime(2011, 8, 17, 6, 31, 31),
#  'pledged': 1145.0,
#  'state': 'canceled',
#  'backers': 24,
#  'country': 'US',
#  'usd pledged': 1145.0,
#  'usd_pledged_real': 1145.0}

# %% [markdown]
# ## Question 1

# %%
max_pledged = collection.aggregate([{"$group" : {"_id" : "$name", "pledged" : {"$max" : "$pledged"}}},{
                                            "$sort": {"pledged" : -1}}])
list(max_pledged)[0:5]
# Out:
# [{'_id': "COOLEST COOLER: 21st Century Cooler that's Actually Cooler",
#   'pledged': 13285226.36},
#  {'_id': 'Pebble 2, Time 2 + All-New Pebble Core', 'pledged': 12779843.49},
#  {'_id': 'Expect the Unexpected. digiFilmï¿½ Camera by YASHICA',
#   'pledged': 10035296.0},
#  {'_id': 'OUYA: A New Kind of Video Game Console', 'pledged': 8596474.58},
#  {'_id': 'The Everyday Backpack, Tote, and Sling', 'pledged': 6565782.5}]

# %% [markdown]
# ## Question 2

# %%
successful_cursor = collection.find({"state": "successful"})

# %%
compteur=0
for document in successful_cursor :
    compteur+=1
print(compteur)
# Out:
# 53040

# %% [markdown]
# ## Question 3

# %%
number_project_category = collection.aggregate([{"$group" : {"_id" : "$category", "count" : {"$sum" : 1}}},{
                                            "$sort": {"count" : -1}}])
list(number_project_category)
# Out:
# [{'_id': 'Product Design', 'count': 8886},
#  {'_id': 'Documentary', 'count': 6498},
#  {'_id': 'Music', 'count': 6229},
#  {'_id': 'Tabletop Games', 'count': 5581},
#  {'_id': 'Shorts', 'count': 4857},
#  {'_id': 'Video Games', 'count': 4799},
#  {'_id': 'Food', 'count': 4612},
#  {'_id': 'Film & Video', 'count': 4003},
#  {'_id': 'Fiction', 'count': 3703},
#  {'_id': 'Nonfiction', 'count': 3390},
#  {'_id': 'Fashion', 'count': 3379},
#  {'_id': 'Art', 'count': 3358},
#  {'_id': 'Apparel', 'count': 2827},
#  {'_id': 'Theater', 'count': 2786},
#  {'_id': 'Rock', 'count': 2707},
#  {'_id': 'Technology', 'count': 2690},
#  {'_id': "Children's Books", 'count': 2686},
#  {'_id': 'Apps', 'count': 2535},
#  {'_id': 'Publishing', 'count': 2332},
#  {'_id': 'Webseries', 'count': 2316},
#  {'_id': 'Photography', 'count': 2239},
#  {'_id': 'Indie Rock', 'count': 2192},
#  {'_id': 'Narrative Film', 'count': 2099},
#  {'_id': 'Web', 'count': 2017},
#  {'_id': 'Comics', 'count': 1931},
#  {'_id': 'Crafts', 'count': 1834},
#  {'_id': 'Country & Folk', 'count': 1790},
#  {'_id': 'Design', 'count': 1641},
#  {'_id': 'Hip-Hop', 'count': 1555},
#  {'_id': 'Hardware', 'count': 1431},
#  {'_id': 'Games', 'count': 1331},
#  {'_id': 'Pop', 'count': 1302},
#  {'_id': 'Painting', 'count': 1288},
#  {'_id': 'Illustration', 'count': 1263},
#  {'_id': 'Public Art', 'count': 1248},
#  {'_id': 'Gadgets', 'count': 1210},
#  {'_id': 'Accessories', 'count': 1204},
#  {'_id': 'Software', 'count': 1194},
#  {'_id': 'Mixed Media', 'count': 1118},
#  {'_id': 'Restaurants', 'count': 1089},
#  {'_id': 'Art Books', 'count': 1065},
#  {'_id': 'Classical Music', 'count': 1064},
#  {'_id': 'Comic Books', 'count': 1032},
#  {'_id': 'Animation', 'count': 1017},
#  {'_id': 'Drinks', 'count': 995},
#  {'_id': 'Playing Cards', 'count': 963},
#  {'_id': 'Comedy', 'count': 923},
#  {'_id': 'Dance', 'count': 901},
#  {'_id': 'Drama', 'count': 871},
#  {'_id': 'Electronic Music', 'count': 858},
#  {'_id': 'Performance Art', 'count': 855},
#  {'_id': 'World Music', 'count': 850},
#  {'_id': 'Graphic Design', 'count': 765},
#  {'_id': 'Sculpture', 'count': 737},
#  {'_id': 'Jazz', 'count': 733},
#  {'_id': 'Graphic Novels', 'count': 702},
#  {'_id': 'Small Batch', 'count': 701},
#  {'_id': 'Food Trucks', 'count': 687},
#  {'_id': 'Journalism', 'count': 672},
#  {'_id': 'Mobile Games', 'count': 650},
#  {'_id': 'Photobooks', 'count': 608},
#  {'_id': 'Plays', 'count': 539},
#  {'_id': 'Poetry', 'count': 532},
#  {'_id': 'Horror', 'count': 525},
#  {'_id': 'Digital Art', 'count': 524},
#  {'_id': 'Periodicals', 'count': 517},
#  {'_id': 'Wearables', 'count': 508},
#  {'_id': 'Farms', 'count': 482},
#  {'_id': 'DIY', 'count': 480},
#  {'_id': 'Jewelry', 'count': 472},
#  {'_id': 'People', 'count': 440},
#  {'_id': 'Faith', 'count': 439},
#  {'_id': 'Woodworking', 'count': 433},
#  {'_id': 'Performances', 'count': 414},
#  {'_id': 'Television', 'count': 401},
#  {'_id': 'Live Games', 'count': 394},
#  {'_id': 'Conceptual Art', 'count': 393},
#  {'_id': 'Footwear', 'count': 379},
#  {'_id': 'Musical', 'count': 367},
#  {'_id': 'Academic', 'count': 367},
#  {'_id': 'DIY Electronics', 'count': 358},
#  {'_id': 'Experimental', 'count': 357},
#  {'_id': 'Radio & Podcasts', 'count': 349},
#  {'_id': 'Ready-to-wear', 'count': 332},
#  {'_id': 'Spaces', 'count': 331},
#  {'_id': 'Young Adult', 'count': 328},
#  {'_id': 'Events', 'count': 322},
#  {'_id': 'Festivals', 'count': 313},
#  {'_id': 'Thrillers', 'count': 302},
#  {'_id': 'Anthologies', 'count': 300},
#  {'_id': 'Architecture', 'count': 300},
#  {'_id': 'Music Videos', 'count': 299},
#  {'_id': 'Fine Art', 'count': 291},
#  {'_id': 'Print', 'count': 288},
#  {'_id': 'Places', 'count': 283},
#  {'_id': 'Action', 'count': 282},
#  {'_id': 'Science Fiction', 'count': 274},
#  {'_id': 'Metal', 'count': 274},
#  {'_id': '3D Printing', 'count': 271},
#  {'_id': 'Webcomics', 'count': 259},
#  {'_id': 'Sound', 'count': 255},
#  {'_id': 'Robots', 'count': 237},
#  {'_id': 'Vegan', 'count': 229},
#  {'_id': 'Nature', 'count': 219},
#  {'_id': 'Cookbooks', 'count': 217},
#  {'_id': 'Childrenswear', 'count': 192},
#  {'_id': 'Gaming Hardware', 'count': 178},
#  {'_id': 'Installations', 'count': 178},
#  {'_id': "Farmer's Markets", 'count': 175},
#  {'_id': 'R&B', 'count': 172},
#  {'_id': 'Candles', 'count': 168},
#  {'_id': 'Camera Equipment', 'count': 165},
#  {'_id': 'Audio', 'count': 164},
#  {'_id': 'Flight', 'count': 158},
#  {'_id': 'Video', 'count': 147},
#  {'_id': 'Interactive Design', 'count': 146},
#  {'_id': 'Zines', 'count': 144},
#  {'_id': 'Space Exploration', 'count': 137},
#  {'_id': 'Fantasy', 'count': 132},
#  {'_id': 'Immersive', 'count': 131},
#  {'_id': 'Family', 'count': 130},
#  {'_id': 'Civic Design', 'count': 130},
#  {'_id': 'Ceramics', 'count': 128},
#  {'_id': 'Punk', 'count': 127},
#  {'_id': 'Literary Journals', 'count': 118},
#  {'_id': 'Community Gardens', 'count': 115},
#  {'_id': 'Blues', 'count': 113},
#  {'_id': 'Calendars', 'count': 112},
#  {'_id': 'Kids', 'count': 109},
#  {'_id': 'Couture', 'count': 108},
#  {'_id': 'Textiles', 'count': 105},
#  {'_id': 'Animals', 'count': 97},
#  {'_id': 'Fabrication Tools', 'count': 96},
#  {'_id': 'Puzzles', 'count': 95},
#  {'_id': 'Makerspaces', 'count': 91},
#  {'_id': 'Movie Theaters', 'count': 90},
#  {'_id': 'Stationery', 'count': 90},
#  {'_id': 'Printing', 'count': 83},
#  {'_id': 'Bacon', 'count': 78},
#  {'_id': 'Knitting', 'count': 78},
#  {'_id': 'Translations', 'count': 76},
#  {'_id': 'Romance', 'count': 74},
#  {'_id': 'Video Art', 'count': 65},
#  {'_id': 'Latin', 'count': 63},
#  {'_id': 'Crochet', 'count': 61},
#  {'_id': 'Workshops', 'count': 59},
#  {'_id': 'Photo', 'count': 58},
#  {'_id': 'Glass', 'count': 51},
#  {'_id': 'Pet Fashion', 'count': 51},
#  {'_id': 'Embroidery', 'count': 49},
#  {'_id': 'Typography', 'count': 44},
#  {'_id': 'Pottery', 'count': 40},
#  {'_id': 'Weaving', 'count': 38},
#  {'_id': 'Quilts', 'count': 32},
#  {'_id': 'Residencies', 'count': 32},
#  {'_id': 'Letterpress', 'count': 24},
#  {'_id': 'Chiptune', 'count': 10},
#  {'_id': 'Literary Spaces', 'count': 10},
#  {'_id': 'Taxidermy', 'count': 7}]

# %% [markdown]
# ## Question 4

# %%
import datetime
d = datetime.datetime(2016, 0o1, 0o1, 0o1)
nb_projetfr = collection.aggregate([{"$match":{"country":"FR","launched" : {'$lt': d}}},{"$group" : {"_id" : "$name", "date" : {"$max" : "$launched"}}}])
len(list(nb_projetfr))
# Out:
# 330

# %% [markdown]
# #### Question 5

# %%
american_project = collection.aggregate([{"$match":{"country":"US","goal" : {'$gt': 200000}}},{"$group" : {"_id" : "$name", "demande" : {"$max" : "$goal"}}},
                                        {
                                            "$sort": {"demande" : -1}}])
list(american_project)
# Out:
# [{'_id': 'Kybernan Holographic Gaming Network', 'demande': 100000000.0},
#  {'_id': 'The Time Jumper', 'demande': 100000000.0},
#  {'_id': 'The Scariest Movie Ever Created', 'demande': 100000000.0},
#  {'_id': 'The Throne : Fall of Lucifer', 'demande': 100000000.0},
#  {'_id': 'The Return Of The Bell Witch Movie', 'demande': 100000000.0},
#  {'_id': 'The Best Kickstarter Video Ever', 'demande': 73000000.0},
#  {'_id': 'The Cultivator Episode 1 Lord Of The Gorgs', 'demande': 50000000.0},
#  {'_id': 'Save the Williamsburg', 'demande': 40000000.0},
#  {'_id': 'Gouddaa series (Canceled)', 'demande': 40000000.0},
#  {'_id': 'equal rights for all campaign', 'demande': 35000000.0},
#  {'_id': 'Intelligent Design: The Series', 'demande': 33000000.0},
#  {'_id': 'Help erase the national debt of the USA', 'demande': 21474836.47},
#  {'_id': 'Flat Creek Agri-Tourism and Outdoor Family Gaming',
#   'demande': 16610000.0},
#  {'_id': 'Jesus Vs The Dragons', 'demande': 10000000.0},
#  {'_id': 'The Confidant', 'demande': 10000000.0},
#  {'_id': "I don't know a comic book?", 'demande': 10000000.0},
#  {'_id': 'Regenerate', 'demande': 10000000.0},
#  {'_id': 'Feature-Length Movie: Secret of the Missing Grave',
#   'demande': 10000000.0},
#  {'_id': 'Tradewinds Terrace. INC', 'demande': 9592440.0},
#  {'_id': 'Ekawa I - The Motion Picture', 'demande': 8000000.0},
#  {'_id': 'Aquaponics system for supplying fresh organic food.',
#   'demande': 8000000.0},
#  {'_id': 'Lateralus | the debut album', 'demande': 7316000.0},
#  {'_id': 'The Journal Library', 'demande': 6000000.0},
#  {'_id': 'Destroy only copy of new Wu-Tang Album', 'demande': 6000000.0},
#  {'_id': 'Turntables Of House', 'demande': 6000000.0},
#  {'_id': 'GAMMA Fight Club', 'demande': 5759042.0},
#  {'_id': 'Cool Roofs! Let the phenomenon begin!', 'demande': 5250000.0},
#  {'_id': 'Refugee Socks', 'demande': 5017511.0},
#  {'_id': 'New Superhero MMO (Among Us) (Canceled)', 'demande': 5000000.0},
#  {'_id': 'The God MC', 'demande': 5000000.0},
#  {'_id': 'Scum Gear-Apparel For The Rest Of Us', 'demande': 5000000.0},
#  {'_id': 'Wasted Entertainment round 2', 'demande': 5000000.0},
#  {'_id': 'Colorvision Films', 'demande': 5000000.0},
#  {'_id': 'Northwoods Gaming Project', 'demande': 5000000.0},
#  {'_id': 'Building A Film Production', 'demande': 5000000.0},
#  {'_id': 'FILM w/ THORA BIRCH, HEATHER MATARAZZO, JENNIFER ELISE COX',
#   'demande': 5000000.0},
#  {'_id': 'Once Upon A Time In Shaolin - For Wu Fans, For Wu People',
#   'demande': 5000000.0},
#  {'_id': "Braddah's Island Style - fresh kitchen & grill",
#   'demande': 5000000.0},
#  {'_id': 'My Mission (Canceled)', 'demande': 5000000.0},
#  {'_id': 'Plaza Capcom USA', 'demande': 5000000.0},
#  {'_id': 'Me2', 'demande': 4000000.0},
#  {'_id': 'Dino Land - A Jungle Park Filled with Dinosaurs!',
#   'demande': 4000000.0},
#  {'_id': "Martin Delgado's Flying Techniques, (2)", 'demande': 4000000.0},
#  {'_id': '9 11 Responders Honored by Statue "The Ascension of Heroes"',
#   'demande': 3730000.0},
#  {'_id': 'DRUMPF THE MUSICAL', 'demande': 3500000.0},
#  {'_id': 'Midnight Nectar', 'demande': 3500000.0},
#  {'_id': "Salvators' Winery & Restaurant", 'demande': 3500000.0},
#  {'_id': 'Everyday Dreamers Living in the Beautiful Struggle',
#   'demande': 3500000.0},
#  {'_id': "Ambrosia'a Boone / Midnight's Nectar", 'demande': 3500000.0},
#  {'_id': 'Project: Nourish', 'demande': 3500000.0},
#  {'_id': 'Monitor,TV,SolarPanel,Slat adjustable cart/dolly',
#   'demande': 3300000.0},
#  {'_id': 'One Ugly Baby', 'demande': 3300000.0},
#  {'_id': 'Book Bros.', 'demande': 3000000.0},
#  {'_id': 'Ride Share', 'demande': 3000000.0},
#  {'_id': 'Immediate Political Accountability Resource (I-PAR)',
#   'demande': 3000000.0},
#  {'_id': 'Tales & Realms - the Beta Project', 'demande': 3000000.0},
#  {'_id': 'NewsRadio Season 6 (Canceled)', 'demande': 3000000.0},
#  {'_id': 'Nightclub', 'demande': 3000000.0},
#  {'_id': 'The LAKE HOPPER is a VTOL Flying Water Craft Made in America',
#   'demande': 3000000.0},
#  {'_id': 'Key of Fate', 'demande': 2900000.0},
#  {'_id': 'Although I Deserve To Die Movie Production', 'demande': 2875000.0},
#  {'_id': 'My a MAZING Academic Profile', 'demande': 2852666.0},
#  {'_id': 'Health Sidekick APP and SIte', 'demande': 2500000.0},
#  {'_id': 'From Ashes', 'demande': 2500000.0},
#  {'_id': 'Environmentally Safe Storm Drains + Parking Lots',
#   'demande': 2500000.0},
#  {'_id': 'Magic SQL .NET', 'demande': 2500000.0},
#  {'_id': 'The Baby', 'demande': 2500000.0},
#  {'_id': 'Blood Will Tell', 'demande': 2500000.0},
#  {'_id': '"Foam" - Reality TV Show for 2015', 'demande': 2500000.0},
#  {'_id': 'Rebuild Enzo Ferrari', 'demande': 2500000.0},
#  {'_id': 'Vixen', 'demande': 2500000.0},
#  {'_id': 'Make A South African Feature Film! (Canceled)',
#   'demande': 2500000.0},
#  {'_id': 'CourEntertainment LLC\'s Video Game Project: "Space-opolis"',
#   'demande': 2464670.0},
#  {'_id': 'Top secret recipes that we all need to know.', 'demande': 2300000.0},
#  {'_id': 'Forbidden Woods (Canceled)', 'demande': 2300000.0},
#  {'_id': 'Worlds Air', 'demande': 2257037.0},
#  {'_id': 'Is That a Gun in Your Pocket ...?', 'demande': 2200000.0},
#  {'_id': 'Homeland', 'demande': 2000000.0},
#  {'_id': 'Death Match', 'demande': 2000000.0},
#  {'_id': 'Save Nature', 'demande': 2000000.0},
#  {'_id': 'The Greatest Escape (Canceled)', 'demande': 2000000.0},
#  {'_id': 'Space Exploration Drone Vehicle', 'demande': 2000000.0},
#  {'_id': 'PySchool.net - Advancing Python in the Classroom',
#   'demande': 2000000.0},
#  {'_id': 'Bazadee Sports (Canceled)', 'demande': 2000000.0},
#  {'_id': 'SANTO 7.13.15 G.M.O. Movie (Canceled)', 'demande': 2000000.0},
#  {'_id': 'Hello Space Boy!', 'demande': 2000000.0},
#  {'_id': 'VOLUNTEERED', 'demande': 2000000.0},
#  {'_id': "Washington's first ethical Erotic dance club", 'demande': 2000000.0},
#  {'_id': "Daniel's Dream", 'demande': 2000000.0},
#  {'_id': "Martin Delgado's Flying Techniques", 'demande': 2000000.0},
#  {'_id': 'As Cine On TV', 'demande': 2000000.0},
#  {'_id': "Mr. Rick's Trading Post", 'demande': 2000000.0},
#  {'_id': 'Backyard Soccer Buddy / Football Mate (Overseas)',
#   'demande': 2000000.0},
#  {'_id': "Zion's Creative Arts Center (Canceled)", 'demande': 2000000.0},
#  {'_id': '"Swoooosh"', 'demande': 2000000.0},
#  {'_id': 'The Manson Obsession (Canceled)', 'demande': 2000000.0},
#  {'_id': 'Gouddaa Sons Of Titan', 'demande': 2000000.0},
#  {'_id': 'The Veronica Mars Movie Project', 'demande': 2000000.0},
#  {'_id': 'RHN - THE REAL HIP-HOP NETWORK TV CHANNEL  DOCUMENTARY',
#   'demande': 2000000.0},
#  {'_id': 'Otaku Club House', 'demande': 1949000.0},
#  {'_id': 'St Patrick of Ireland biography film project', 'demande': 1875000.0},
#  {'_id': 'LLORONA THE LEGEND (Canceled)', 'demande': 1870000.0},
#  {'_id': 'Harishwar Center for Arts, Spirituality & Sustainability',
#   'demande': 1800000.0},
#  {'_id': 'COEXISTENCE the Movie (Canceled)', 'demande': 1750000.0},
#  {'_id': '20th Century @ War (Canceled)', 'demande': 1745000.0},
#  {'_id': 'Tribes of the CaveFan', 'demande': 1672000.0},
#  {'_id': 'Dragon Bones: the Future of Electronic Fun (Canceled)',
#   'demande': 1625000.0},
#  {'_id': 'SHIELDS Empowering Consumer Health and Protection',
#   'demande': 1600000.0},
#  {'_id': 'The Hill (Canceled)', 'demande': 1575000.0},
#  {'_id': 'Talk Is Cheap -  from Academy Award Winner Barrie M. Osborne',
#   'demande': 1500000.0},
#  {'_id': "Niwot's Curse", 'demande': 1500000.0},
#  {'_id': "The Cancer Patient's Film Project", 'demande': 1500000.0},
#  {'_id': 'Technerd.com Needs support International AD campaign',
#   'demande': 1500000.0},
#  {'_id': 'Dead Drunk (Canceled)', 'demande': 1500000.0},
#  {'_id': 'Gluten Free Fabulous', 'demande': 1500000.0},
#  {'_id': 'Tha Life', 'demande': 1500000.0},
#  {'_id': 'PartyPronto', 'demande': 1500000.0},
#  {'_id': 'Fidelis Cloud (Canceled)', 'demande': 1500000.0},
#  {'_id': 'CineBlock 2.0 (Canceled)', 'demande': 1500000.0},
#  {'_id': "Harambe's Revenge", 'demande': 1500000.0},
#  {'_id': 'The Road to Forgiveness', 'demande': 1500000.0},
#  {'_id': 'Get 100,000 Copies Of My Neighborhood Book To Children',
#   'demande': 1500000.0},
#  {'_id': 'koi farm', 'demande': 1500000.0},
#  {'_id': 'G.H.O.S.T. / Hydrogen On-Demand', 'demande': 1400000.0},
#  {'_id': 'Indie film - Think "Days of Thunder" on a motorcycle track!',
#   'demande': 1400000.0},
#  {'_id': "Mustard Pancakes - Oogleberry's Journey Home", 'demande': 1400000.0},
#  {'_id': 'ABB Movie Project', 'demande': 1400000.0},
#  {'_id': 'The Clambake: The History of the Pebble Beach Pro-Am',
#   'demande': 1350000.0},
#  {'_id': 'INSIDEOUT (Canceled)', 'demande': 1250000.0},
#  {'_id': 'The Newest Hottest Spike Lee Joint', 'demande': 1250000.0},
#  {'_id': 'The Life (Canceled)', 'demande': 1250000.0},
#  {'_id': '" A STORY ABOUT LOVE "  motion picture production',
#   'demande': 1200000.0},
#  {'_id': 'Patient Zero: Outbreak', 'demande': 1200000.0},
#  {'_id': 'a really cool Super Cybermobile!', 'demande': 1200000.0},
#  {'_id': '"MATA HARI"', 'demande': 1200000.0},
#  {'_id': 'Heli Harbor', 'demande': 1200000.0},
#  {'_id': 'MotoRide quickely on demand with low cost in one click app!',
#   'demande': 1200000.0},
#  {'_id': 'Angelz Landing the Movie', 'demande': 1200000.0},
#  {'_id': 'GolferVox', 'demande': 1200000.0},
#  {'_id': 'Oregon Ducks.  A Love Story (Canceled)', 'demande': 1200000.0},
#  {'_id': 'Dolphinese! Talk to Dolphins in their own native language!',
#   'demande': 1171000.0},
#  {'_id': 'HELLO AMERICA THE WORLD IS WATCHING', 'demande': 1150000.0},
#  {'_id': 'Archon-01 Initiation', 'demande': 1125789.0},
#  {'_id': 'The Hawaiian Girl Art Studio (Canceled)', 'demande': 1100000.0},
#  {'_id': 'Obduction', 'demande': 1100000.0},
#  {'_id': "Enjoy The Old Children's Home: Historic Preservation",
#   'demande': 1100000.0},
#  {'_id': 'The Nicholas Project  - Keeping Christ in Christmas',
#   'demande': 1085000.0},
#  {'_id': 'Montgomery Al Concert 5FDP and VOLBEAT', 'demande': 1040000.0},
#  {'_id': 'TEST (Canceled)', 'demande': 1000001.0},
#  {'_id': "Club Toke'n Token's: Video Arcade & Smoke Lounge (Canceled)",
#   'demande': 1000000.0},
#  {'_id': '50/365: America 2014', 'demande': 1000000.0},
#  {'_id': 'Chihuly Installation for Orlando (Pulse Nightclub)',
#   'demande': 1000000.0},
#  {'_id': 'ARANAGA STUDIOS.', 'demande': 1000000.0},
#  {'_id': 'Point of Sale Project', 'demande': 1000000.0},
#  {'_id': 'Wall Scaler', 'demande': 1000000.0},
#  {'_id': '" Radio Reunion " - The Movie. (Canceled)', 'demande': 1000000.0},
#  {'_id': 'With the Web in the Front', 'demande': 1000000.0},
#  {'_id': 'Kuthoomi App', 'demande': 1000000.0},
#  {'_id': 'TickerPix App (Fund for future updates)', 'demande': 1000000.0},
#  {'_id': '"The Warrens Wraith"', 'demande': 1000000.0},
#  {'_id': 'Eazy Coin', 'demande': 1000000.0},
#  {'_id': 'KosLo- Fixing the broken car buying experience! (Canceled)',
#   'demande': 1000000.0},
#  {'_id': 'Sweet Mara film project', 'demande': 1000000.0},
#  {'_id': 'Bronze twin-sculpture of Nelson and Zenani (ggd) Mandela',
#   'demande': 1000000.0},
#  {'_id': 'Film Adaptation of "The Traveler"', 'demande': 1000000.0},
#  {'_id': 'Supreme Life Foods', 'demande': 1000000.0},
#  {'_id': 'LeBron James Redemption Statue', 'demande': 1000000.0},
#  {'_id': 'The Book on Comedy', 'demande': 1000000.0},
#  {'_id': 'Get Em Up', 'demande': 1000000.0},
#  {'_id': '"anonymous (street meat)" (Canceled)', 'demande': 1000000.0},
#  {'_id': 'Asynchronicity Shell', 'demande': 1000000.0},
#  {'_id': 'The Surrender Movie Project', 'demande': 1000000.0},
#  {'_id': 'Bay Area Snow Park', 'demande': 1000000.0},
#  {'_id': 'Connect Games', 'demande': 1000000.0},
#  {'_id': 'Thundercats!!!! Hooooooooooooo!!!!!!!! (Canceled)',
#   'demande': 1000000.0},
#  {'_id': 'Xybears The Last Heroes', 'demande': 1000000.0},
#  {'_id': 'SULTAN OF SCRAPE', 'demande': 1000000.0},
#  {'_id': 'Fires of Strife', 'demande': 1000000.0},
#  {'_id': 'Sonic Chao World fan game (Canceled)', 'demande': 1000000.0},
#  {'_id': "Dutch's Kegs", 'demande': 1000000.0},
#  {'_id': 'QUICK STANCE', 'demande': 1000000.0},
#  {'_id': 'coreXtreme Afterburner Core Bodyweight Fitness Machine',
#   'demande': 1000000.0},
#  {'_id': 'SIAAB Technology - No more deaths!', 'demande': 1000000.0},
#  {'_id': '5 Degrees of Separation (Canceled)', 'demande': 1000000.0},
#  {'_id': "Mom, I'm Marrying a Hybrid; Don't Tell Dad Yet!",
#   'demande': 1000000.0},
#  {'_id': 'Breakfast 24/7', 'demande': 1000000.0},
#  {'_id': '"Hill" (11 For 11) (From the writer of Rudy & Hoosiers)',
#   'demande': 1000000.0},
#  {'_id': 'MICHIGAN - HIGH CALIBER SCIENCE FICTION', 'demande': 1000000.0},
#  {'_id': 'This is my dream (Este es mi sue?o)', 'demande': 1000000.0},
#  {'_id': 'The scariest movie ever', 'demande': 1000000.0},
#  {'_id': 'ONE DEGREE, a productive social network', 'demande': 1000000.0},
#  {'_id': 'Raising Money For My Book To Get On Film!', 'demande': 1000000.0},
#  {'_id': 'Shroud of the Avatar: Forsaken Virtues', 'demande': 1000000.0},
#  {'_id': 'UJ-Innovative Fashion Designer', 'demande': 1000000.0},
#  {'_id': 'The Original Good Times Cast Movie', 'demande': 1000000.0},
#  {'_id': 'OXYGEN FROM BOOKS (Canceled)', 'demande': 1000000.0},
#  {'_id': 'Save the Victory Theatre (Canceled)', 'demande': 1000000.0},
#  {'_id': 'Camp Oak Hallows - A Wizarding World Experience',
#   'demande': 1000000.0},
#  {'_id': 'Jesus Christ!', 'demande': 1000000.0},
#  {'_id': 'Avenge (Canceled)', 'demande': 1000000.0},
#  {'_id': 'Phoenix Rising', 'demande': 1000000.0},
#  {'_id': 'Conscious Conscience', 'demande': 1000000.0},
#  {'_id': 'Morons4Money - Set Bob On Fire (Suspended)', 'demande': 1000000.0},
#  {'_id': "The world's first crowd funded millionaire documentary",
#   'demande': 1000000.0},
#  {'_id': 'I H8 Math: A Pre-Algebra Guide', 'demande': 1000000.0},
#  {'_id': 'The Climate Zombies', 'demande': 1000000.0},
#  {'_id': "Kitty's Secret Activities Memoir", 'demande': 1000000.0},
#  {'_id': '"Secrets"', 'demande': 1000000.0},
#  {'_id': 'Shaft in Asia Featured Film', 'demande': 1000000.0},
#  {'_id': 'Renaissance Men', 'demande': 1000000.0},
#  {'_id': 'Fan Made Platinum Artist (Canceled)', 'demande': 1000000.0},
#  {'_id': 'Turtle Rocket Books', 'demande': 1000000.0},
#  {'_id': 'Zafirro. Sapphire Blade Razor.', 'demande': 1000000.0},
#  {'_id': 'gig', 'demande': 1000000.0},
#  {'_id': 'From Dawson to Jackson Vineyards', 'demande': 1000000.0},
#  {'_id': 'Michigan Fusion Corporation', 'demande': 1000000.0},
#  {'_id': 'The Good Fight of Faith', 'demande': 1000000.0},
#  {'_id': 'The Brooklyn Album', 'demande': 1000000.0},
#  {'_id': 'College Football Championship Game (Canceled)',
#   'demande': 1000000.0},
#  {'_id': 'Window- Virtual Reality Holocaust Education', 'demande': 1000000.0},
#  {'_id': 'Hawkendoo: The Telepathic Spy', 'demande': 1000000.0},
#  {'_id': 'Funding for a 1950s Museum in Tampa Bay (Canceled)',
#   'demande': 1000000.0},
#  {'_id': 'Designed snare drum heads (Canceled)', 'demande': 1000000.0},
#  {'_id': 'New Music!!!', 'demande': 1000000.0},
#  {'_id': 'Discovering Hope', 'demande': 1000000.0},
#  {'_id': 'mr.dj', 'demande': 1000000.0},
#  {'_id': 'SideJobs (Canceled)', 'demande': 1000000.0},
#  {'_id': 'Oblivion Seed', 'demande': 1000000.0},
#  {'_id': 'Treagan', 'demande': 1000000.0},
#  {'_id': 'The Holy Will is a Christian Ministry:', 'demande': 1000000.0},
#  {'_id': 'U-Dot Creative Space System', 'demande': 999000.0},
#  {'_id': 'Zero Point!! Game Console Upgrade to the Future',
#   'demande': 999000.0},
#  {'_id': 'Robotic Handling System', 'demande': 998000.0},
#  {'_id': 'The Revival of Royal Ringball ~ A Sport of the Maya Gods.',
#   'demande': 995000.0},
#  {'_id': 'THE PRIZE GUYS - a coming-of-age comedy drama feature film',
#   'demande': 987000.0},
#  {'_id': 'Chucky:  Wanna Play? (Canceled)', 'demande': 925000.0},
#  {'_id': 'W.A.S.T.E TeleVision Innovative Online Broadcasting Platform',
#   'demande': 917000.0},
#  {'_id': "LumiaNova, The world's largest, greenest, light concert!",
#   'demande': 900000.0},
#  {'_id': 'Cast Irons Steakhouse', 'demande': 900000.0},
#  {'_id': 'Sonic Entertainment Corp', 'demande': 900000.0},
#  {'_id': 'Planetary Annihilation - A Next Generation RTS',
#   'demande': 900000.0},
#  {'_id': "THE YING YANG MURDER MYSTERY'S (Canceled)", 'demande': 900000.0},
#  {'_id': 'Ossus Online: The Rise of Virtue (Canceled)', 'demande': 900000.0},
#  {'_id': 'Auraspark', 'demande': 900000.0},
#  {'_id': 'After Reset RPG', 'demande': 900000.0},
#  {'_id': 'Realms of Goldesia - Player-Driven Virtual Reality MMORPG',
#   'demande': 900000.0},
#  {'_id': 'Mobile Space Camp (Canceled)', 'demande': 900000.0},
#  {'_id': 'Snowyville (Canceled)', 'demande': 900000.0},
#  {'_id': 'Underground Art and Conservation Museum in Midcoast Maine',
#   'demande': 900000.0},
#  {'_id': 'Chronicles of Elyria - Epic Story MMORPG with Aging & Death',
#   'demande': 900000.0},
#  {'_id': 'DANCE, DANCE - Guinness World Record Dance Event',
#   'demande': 900000.0},
#  {'_id': '5k Truffles Orchard - Adopt A Tree Today.', 'demande': 880000.0},
#  {'_id': '??AP Computer Science and Mobile App School', 'demande': 879000.0},
#  {'_id': 'Pallet Wars, Part 1...Two More Weeks and Billions Are Ours!!',
#   'demande': 875000.0},
#  {'_id': 'The Electronic Kids Gym or The Electronic Family Gym',
#   'demande': 850000.0},
#  {'_id': '207 - The Documentary (Canceled)', 'demande': 845000.0},
#  {'_id': 'The Crime Busters (Canceled)', 'demande': 840000.0},
#  {'_id': 'Yolotag - Live it, Prove it. Get credit for your adventure!!',
#   'demande': 825000.0},
#  {'_id': 'Miss Wisenheimer and the Aliens', 'demande': 822996.0},
#  {'_id': 'MegaCafe Gaming and coffee 24/7', 'demande': 800000.0},
#  {'_id': 'Heavy Gear Assault (Canceled)', 'demande': 800000.0},
#  {'_id': 'Crowfall - Throne War PC MMO', 'demande': 800000.0},
#  {'_id': 'Organic Dates and Papaya New Plantation', 'demande': 800000.0},
#  {'_id': 'RED ASH - The Indelible Legend', 'demande': 800000.0},
#  {'_id': 'Visual Legal Dictionary', 'demande': 800000.0},
#  {'_id': "Mama's: Sweet & Healthy!", 'demande': 800000.0},
#  {'_id': 'UNITY THE MOVIE', 'demande': 800000.0},
#  {'_id': 'Pono Music - Where Your Soul Rediscovers Music',
#   'demande': 800000.0},
#  {'_id': 'American Pick Inc.', 'demande': 800000.0},
#  {'_id': 'Kurt Vonnegut Museum in his Childhood Home', 'demande': 800000.0},
#  {'_id': 'The Two-Front War', 'demande': 800000.0},
#  {'_id': 'SUBJECTIVE', 'demande': 800000.0},
#  {'_id': 'SAVING COUNCIL', 'demande': 797267.0},
#  {'_id': 'Crayfish Sports Bar', 'demande': 795000.0},
#  {'_id': 'Destiny 1', 'demande': 781325.0},
#  {'_id': 'Mayacama Chocolate-Bean-to-Bar Craft Chocolate, Napa,Ca',
#   'demande': 780000.0},
#  {'_id': 'Family Fueled- A Trans Am Reality Show', 'demande': 780000.0},
#  {'_id': 'The Fascination', 'demande': 780000.0},
#  {'_id': 'SLAPSHOT HOCKEY', 'demande': 750000.0},
#  {'_id': 'The Katy Incident', 'demande': 750000.0},
#  {'_id': 'Mega Music Artist PlayApps', 'demande': 750000.0},
#  {'_id': 'The Adventures of Billy Buskirk', 'demande': 750000.0},
#  {'_id': 'Shadow Mansion', 'demande': 750000.0},
#  {'_id': 'Puzzle Camp', 'demande': 750000.0},
#  {'_id': 'Experience "Galaxy"', 'demande': 750000.0},
#  {'_id': 'Need a Ride?', 'demande': 750000.0},
#  {'_id': 'Trials of Ascension: A truly innovative MMORPG (Canceled)',
#   'demande': 750000.0},
#  {'_id': 'Drive with Lynk', 'demande': 750000.0},
#  {'_id': 'The Flea Trap', 'demande': 740000.0},
#  {'_id': 'The Adventures of Brent & Ben! Season 1, 2, & 3 Kickstarter',
#   'demande': 700000.0},
#  {'_id': 'Independent Broadcasting Company', 'demande': 700000.0},
#  {'_id': "EDM 2015 Dj's United", 'demande': 700000.0},
#  {'_id': 'A true look into Islam and The United States of America',
#   'demande': 700000.0},
#  {'_id': 'AIRBLADE:  Extreme Hockey', 'demande': 700000.0},
#  {'_id': 'New Sports Industry', 'demande': 700000.0},
#  {'_id': 'HOWEVER YOU MOVE', 'demande': 700000.0},
#  {'_id': 'HULLABALOO TN ROCK FESTIVAL', 'demande': 700000.0},
#  {'_id': 'SANTA MARIA: THE FIRST VOYAGE', 'demande': 700000.0},
#  {'_id': 'Breakfast Drone-Delivery System', 'demande': 700000.0},
#  {'_id': 'World of Kingdoms ~ New MMORPG', 'demande': 700000.0},
#  {'_id': 'Villa Majutiwil, Dream Place to Live and Retire',
#   'demande': 700000.0},
#  {'_id': 'BalletCon', 'demande': 700000.0},
#  {'_id': 'SpeedyLeafer', 'demande': 700000.0},
#  {'_id': 'CIRCLE OF DOORS Major Motion Picture Development',
#   'demande': 700000.0},
#  {'_id': 'Verbi Security', 'demande': 696800.0},
#  {'_id': 'Fast eddies spaghetti.  100% organic', 'demande': 695000.0},
#  {'_id': 'SIGNOOS - Free EDU Series for Deaf Schools around the world.',
#   'demande': 685500.0},
#  {'_id': 'Between The Bars - Elliott Smith', 'demande': 685000.0},
#  {'_id': 'The Magical Mystery Show featuring The Last Great Wizard',
#   'demande': 685000.0},
#  {'_id': 'The Risen', 'demande': 675000.0},
#  {'_id': "Aberford: A video game of zombies and 50's housewives",
#   'demande': 675000.0},
#  {'_id': 'The Momentum Dryer & UpFlow Technology (Consumer Model)',
#   'demande': 650000.0},
#  {'_id': 'The Bill Nye Film', 'demande': 650000.0},
#  {'_id': 'Endless Dreams Pillow / Adjustable pillow', 'demande': 650000.0},
#  {'_id': 'Music, Magic, Energy and GOD', 'demande': 650000.0},
#  {'_id': 'An Old Fashion Butcher Shop', 'demande': 650000.0},
#  {'_id': 'Grandeur Paradigm', 'demande': 650000.0},
#  {'_id': 'Portraits of War', 'demande': 635000.0},
#  {'_id': 'Transgender Documentary on TLC "My Transgender Life"',
#   'demande': 600000.0},
#  {'_id': 'I-Tem brand Wine Dispenser', 'demande': 600000.0},
#  {'_id': 'La Casa de Vida Wellness Center', 'demande': 600000.0},
#  {'_id': 'RED CARD: A FILM ABOUT FIFA (Canceled)', 'demande': 600000.0},
#  {'_id': "Paco's Tacos", 'demande': 600000.0},
#  {'_id': 'Descon 8 Standard - Structural Engineering Software',
#   'demande': 600000.0},
#  {'_id': 'Setupshopz.com', 'demande': 600000.0},
#  {'_id': 'Unsung Story: Tale of the Guardians', 'demande': 600000.0},
#  {'_id': 'Birth of Man - A Minecraft Feature Film (Canceled)',
#   'demande': 600000.0},
#  {'_id': 'Pushed.', 'demande': 600000.0},
#  {'_id': 'ANIMAL HOUSE: a series for people who LOVE animals!',
#   'demande': 600000.0},
#  {'_id': 'Trials of Ascension (Canceled)', 'demande': 600000.0},
#  {'_id': 'A Self-Sufficient Sober Living Farm', 'demande': 600000.0},
#  {'_id': 'MyWorld', 'demande': 600000.0},
#  {'_id': 'Motor Sports Mailboxes', 'demande': 600000.0},
#  {'_id': 'Help me get a 3D Immersive Naruto MMORPG created',
#   'demande': 600000.0},
#  {'_id': 'Maebar Restaurant & Lounge', 'demande': 584000.0},
#  {'_id': 'CULT COUNTY by Renegade Kid', 'demande': 580000.0},
#  {'_id': 'Juntos - Our Unsocial Identity', 'demande': 580000.0},
#  {'_id': 'MY TINSEL TOWN (Canceled)', 'demande': 577000.0},
#  {'_id': 'Umdlalo (Canceled)', 'demande': 575000.0},
#  {'_id': 'The Secret Ninja Cat World Mobile App', 'demande': 562000.0},
#  {'_id': 'Dragonï¿½s Lair: The Movie (Canceled)', 'demande': 550000.0},
#  {'_id': 'Blueprint (Canceled)', 'demande': 550000.0},
#  {'_id': 'Paintball Colosseum', 'demande': 550000.0},
#  {'_id': 'HeartForCancer.com', 'demande': 550000.0},
#  {'_id': "DJ's Country Saloon", 'demande': 550000.0},
#  {'_id': 'Crescent Moon Spirits', 'demande': 550000.0},
#  {'_id': 'CineBlock the gaming spot (Canceled)', 'demande': 550000.0},
#  {'_id': 'Black Arts Matter', 'demande': 550000.0},
#  {'_id': 'ONEIDNET Social Professional Commercial Corporate Platform',
#   'demande': 545539.0},
#  {'_id': 'Kllabo - Inventing gone viral', 'demande': 537600.0},
#  {'_id': 'Panacea2', 'demande': 535000.0},
#  {'_id': 'Slickview', 'demande': 529000.0},
#  {'_id': '2d3D HierSwipe', 'demande': 527000.0},
#  {'_id': 'Nostalgia Arcade', 'demande': 525000.0},
#  {'_id': 'An American Veterans Greatest Road Trip of North America',
#   'demande': 525000.0},
#  {'_id': '"PEOPLE OF ..." inspiring people with beautiful stories!',
#   'demande': 510000.0},
#  {'_id': 'City of Rain (Canceled)', 'demande': 500000.0},
#  {'_id': 'The Everyday Backpack, Tote, and Sling', 'demande': 500000.0},
#  {'_id': 'Japanese Fighting Fish & Japanese Fighting Fish Hold Em',
#   'demande': 500000.0},
#  {'_id': 'ZION (Canceled)', 'demande': 500000.0},
#  {'_id': 'SKYDANCE', 'demande': 500000.0},
#  {'_id': 'Judged At First Sight', 'demande': 500000.0},
#  {'_id': 'Herbal Sex Tea', 'demande': 500000.0},
#  {'_id': '"Q Sheba" (Canceled)', 'demande': 500000.0},
#  {'_id': 'Republique by Camouflaj + Logan', 'demande': 500000.0},
#  {'_id': 'For All The Tea In China', 'demande': 500000.0},
#  {'_id': 'Home is Where I Die... (Canceled)', 'demande': 500000.0},
#  {'_id': 'Milkbe Strollers The Safest Most Modern stroller.',
#   'demande': 500000.0},
#  {'_id': 'END - The Online Zombie Survival RTS (Canceled)',
#   'demande': 500000.0},
#  {'_id': 'Larceny Lock: Make Your Door Kick-in Proof', 'demande': 500000.0},
#  {'_id': 'Freshg?rd: Organic for all! (Canceled)', 'demande': 500000.0},
#  {'_id': 'Nephilim, Nazis and the New World Order', 'demande': 500000.0},
#  {'_id': 'The new "Best Restaurant" Academy in town.', 'demande': 500000.0},
#  {'_id': 'Ending climate change, one vegan at a time', 'demande': 500000.0},
#  {'_id': 'Candy store & Deli in Clearwater Beach', 'demande': 500000.0},
#  {'_id': 'Virtual Reality - Duck Hunter', 'demande': 500000.0},
#  {'_id': 'Ionobell - Green, Sustainable Batteries', 'demande': 500000.0},
#  {'_id': 'No More Heroes:The movie', 'demande': 500000.0},
#  {'_id': 'BUILDING BRIDGES - Film Based on a True Story (Canceled)',
#   'demande': 500000.0},
#  {'_id': 'Crafting Series "Enjoy the Moments" by Megan Elizabeth',
#   'demande': 500000.0},
#  {'_id': 'Eclessia Ascending', 'demande': 500000.0},
#  {'_id': 'Nichol Alexander', 'demande': 500000.0},
#  {'_id': 'StreetGodz- Body Enhancing Shoe', 'demande': 500000.0},
#  {'_id': 'Hoverboard: The Next Evolution in Personal Electric Mobility',
#   'demande': 500000.0},
#  {'_id': 'The Sweet Spot', 'demande': 500000.0},
#  {'_id': 'Gabriel Device - Free energy for everyone', 'demande': 500000.0},
#  {'_id': "Moreno's Art (Canceled)", 'demande': 500000.0},
#  {'_id': 'Back the Booster', 'demande': 500000.0},
#  {'_id': 'Trail Of Fears Haunted House', 'demande': 500000.0},
#  {'_id': 'Vehroot Shelf | Use Your Phone or Tablet as Your Car Stereo',
#   'demande': 500000.0},
#  {'_id': 'Color Pixel - Paint By Number (Build a #1 Ranked App)',
#   'demande': 500000.0},
#  {'_id': 'Photo Caffe', 'demande': 500000.0},
#  {'_id': 'ENERGY FLOW NETWORK:  24/HR Platform for Everything Energy',
#   'demande': 500000.0},
#  {'_id': 'Theory of the Evolution of the Moral Idiot', 'demande': 500000.0},
#  {'_id': 'P.U.R.E. Gamers', 'demande': 500000.0},
#  {'_id': 'Two Guys SpaceVenture - by the creators of Space Quest',
#   'demande': 500000.0},
#  {'_id': "ZTE 'Project CSX' Phone - Hands Free, Eye Tracking Device",
#   'demande': 500000.0},
#  {'_id': 'Wish-Li.com: Give and receive the perfect gift, every time!',
#   'demande': 500000.0},
#  {'_id': 'The Scott Emo Show - New Talk Show Inspired To Change Lives',
#   'demande': 500000.0},
#  {'_id': 'Fuel-X-Tender', 'demande': 500000.0},
#  {'_id': 'Cancer Cure-The Movie-Big Pharma, Russian Mafia, One Doctor.',
#   'demande': 500000.0},
#  {'_id': "Pontruff's Pop Shop, Pizza, and Punk Rock", 'demande': 500000.0},
#  {'_id': 'DJBennett.com The World of SPORTING LUXURY', 'demande': 500000.0},
#  {'_id': 'Asbury Park, USA', 'demande': 500000.0},
#  {'_id': 'Canopus Weekplanner watch launch A.Manzoni & Fils',
#   'demande': 500000.0},
#  {'_id': 'The Prophet Chronicles: Redemption - Pre-Production',
#   'demande': 500000.0},
#  {'_id': 'Robot Fighting Championship', 'demande': 500000.0},
#  {'_id': 'Sushiman School', 'demande': 500000.0},
#  {'_id': "Global Coin Exchange you'll be glad you did!!! (Canceled)",
#   'demande': 500000.0},
#  {'_id': 'Pontiac Aztek Conservation and Customizing', 'demande': 500000.0},
#  {'_id': 'AMBROV X: A Story-Driven, Science Fiction RPG (Canceled)',
#   'demande': 500000.0},
#  {'_id': 'Honolulu Haze (Canceled)', 'demande': 500000.0},
#  {'_id': 'WAR - 4 player Custom built colectors chess set (Oak & Glas)',
#   'demande': 500000.0},
#  {'_id': 'Ghetto America', 'demande': 500000.0},
#  {'_id': 'Shadowrun Online', 'demande': 500000.0},
#  {'_id': '"PAQUP & GO!" - Discover Your Groups Destinations!',
#   'demande': 500000.0},
#  {'_id': 'Flight Experience - Kansas City (Canceled)', 'demande': 500000.0},
#  {'_id': 'The Phone for Humans', 'demande': 500000.0},
#  {'_id': 'Save Me From This Upcoming Election', 'demande': 500000.0},
#  {'_id': "Gamer's Hotel USA", 'demande': 500000.0},
#  {'_id': 'LeisureMaps', 'demande': 500000.0},
#  {'_id': 'LUV & PERVERSITY IN THE EAST VILLAGE', 'demande': 500000.0},
#  {'_id': 'Family Entertainment Center, Rankin County MS', 'demande': 500000.0},
#  {'_id': 'Guitar Godz VR: A 3D Rock Music Game', 'demande': 500000.0},
#  {'_id': 'Sydewynder Wheels', 'demande': 500000.0},
#  {'_id': 'Landshape Modeling and Design', 'demande': 500000.0},
#  {'_id': 'STD-Verify: An online STD verification website.',
#   'demande': 500000.0},
#  {'_id': 'Voltara Battle for the Galaxy', 'demande': 500000.0},
#  {'_id': 'Spokane Drive In Theater', 'demande': 500000.0},
#  {'_id': 'Orion OGS: Affordable 3-in-1 Computer, Media & Gaming System',
#   'demande': 500000.0},
#  {'_id': 'Transform the Wedding Cake House Into the Providence Inn',
#   'demande': 500000.0},
#  {'_id': 'SPREADSHEET HEAVEN', 'demande': 500000.0},
#  {'_id': 'THE AFTERLIFE FILES', 'demande': 500000.0},
#  {'_id': 'Ride - Your Personal Driver', 'demande': 500000.0},
#  {'_id': 'Byson farm and eatery', 'demande': 500000.0},
#  {'_id': 'Project Snowstorm', 'demande': 500000.0},
#  {'_id': 'Oindexter (Canceled)', 'demande': 500000.0},
#  {'_id': "Fund and support on Keyon Brown's Hip Hop and Rap Career",
#   'demande': 500000.0},
#  {'_id': "World's First Smart Football", 'demande': 500000.0},
#  {'_id': 'Welcome to the Wonderful World of AIDS', 'demande': 500000.0},
#  {'_id': 'World War 3 the Fight of the People', 'demande': 500000.0},
#  {'_id': 'The Darkest Dawn', 'demande': 500000.0},
#  {'_id': 'Offer & Compromise', 'demande': 500000.0},
#  {'_id': 'Slot Car Mania!!!', 'demande': 500000.0},
#  {'_id': 'Get Me Me Kids (Books, Music, Film & Games)', 'demande': 500000.0},
#  {'_id': 'Can You SCRUMMY?!!!', 'demande': 500000.0},
#  {'_id': 'CARE365', 'demande': 500000.0},
#  {'_id': 'Save Gawker.com', 'demande': 500000.0},
#  {'_id': "A GOOD MAN'S DECISION", 'demande': 500000.0},
#  {'_id': 'STAR WARS -A Game the Fans Want- (Suspended)', 'demande': 500000.0},
#  {'_id': 'Custom Water-Cooled Laptop Backplate', 'demande': 500000.0},
#  {'_id': 'FJE REVOLT', 'demande': 500000.0},
#  {'_id': 'Lady Panther "Bow or Bullet"', 'demande': 500000.0},
#  {'_id': 'YOURECG', 'demande': 500000.0},
#  {'_id': 'Cancelled :(', 'demande': 500000.0},
#  {'_id': "The Making of 'Picture Perfect?' (Canceled)", 'demande': 500000.0},
#  {'_id': 'The Homeless art Studio (pic from AP) FUCKING HELP OUT',
#   'demande': 500000.0},
#  {'_id': 'EXFYRE!!! THE FIRE EXTINGUISHER THAT NO OTHER CAN COMPARE.',
#   'demande': 500000.0},
#  {'_id': 'VR Extreme', 'demande': 500000.0},
#  {'_id': 'my animated series (Canceled)', 'demande': 500000.0},
#  {'_id': '"The Irwins" : Animated Series', 'demande': 500000.0},
#  {'_id': 'Community Farm', 'demande': 500000.0},
#  {'_id': 'Project Ravensdale (Canceled)', 'demande': 500000.0},
#  {'_id': 'Raising My SuperKidsï¿½! Mobile Social Game (Canceled)',
#   'demande': 500000.0},
#  {'_id': 'THE MESSAGE', 'demande': 500000.0},
#  {'_id': 'Jog the Dog: Indoor Track and Dog Exercise Field',
#   'demande': 500000.0},
#  {'_id': 'Stream Live Party', 'demande': 500000.0},
#  {'_id': 'Pathfinder: Kingmaker', 'demande': 500000.0},
#  {'_id': 'Not My Flag', 'demande': 500000.0},
#  {'_id': 'Qubi: The Media Center Reinvented', 'demande': 500000.0},
#  {'_id': 'By The End Of This Book', 'demande': 500000.0},
#  {'_id': 'GermBGone (Canceled)', 'demande': 500000.0},
#  {'_id': 'One Good Deed (Canceled)', 'demande': 500000.0},
#  {'_id': 'Days End Feature Film', 'demande': 500000.0},
#  {'_id': 'Watscene', 'demande': 500000.0},
#  {'_id': 'Shades of Gray', 'demande': 500000.0},
#  {'_id': 'USB Digital Shoe', 'demande': 500000.0},
#  {'_id': 'Have Steam Engine, Will Travel', 'demande': 500000.0},
#  {'_id': 'modds', 'demande': 500000.0},
#  {'_id': 'Messages to Heaven', 'demande': 500000.0},
#  {'_id': 'The Fantom Messenger', 'demande': 500000.0},
#  {'_id': 'Ride Share Revolution (Canceled)', 'demande': 500000.0},
#  {'_id': 'THOR GENESIS - A Desilu Studios Production', 'demande': 500000.0},
#  {'_id': 'Sons & Daughters of Africa Awards [Global Broadcast]',
#   'demande': 499999.0},
#  {'_id': 'Grown Folk', 'demande': 498129.55},
#  {'_id': 'inPatient Help, Acuity & Communication Tablet System iPHACTS',
#   'demande': 497900.0},
#  {'_id': 'My Russian Kitchen: Love Story', 'demande': 495000.0},
#  {'_id': 'Batman v Iron Man : The Jokers [fan film project] (Canceled)',
#   'demande': 490000.0},
#  {'_id': 'Reality Gaming (Canceled)', 'demande': 485000.0},
#  {'_id': 'Game Studio', 'demande': 480000.0},
#  {'_id': 'Infinity Blade Chronicles', 'demande': 480000.0},
#  {'_id': 'Shark Tooth Edger', 'demande': 475000.0},
#  {'_id': 'Adventure through the Amazon River (Canceled)', 'demande': 475000.0},
#  {'_id': 'Southern Boys Country Cooking', 'demande': 475000.0},
#  {'_id': 'Ozark Mountain Ranch', 'demande': 466000.0},
#  {'_id': 'Winged Warriors the Movie', 'demande': 462500.0},
#  {'_id': 'Redeye Visuals', 'demande': 450000.0},
#  {'_id': 'Amazing America - Tornado Alley (Canceled)', 'demande': 450000.0},
#  {'_id': 'Good Grief, Zombies', 'demande': 450000.0},
#  {'_id': 'Magic Mountain Farm (Canceled)', 'demande': 450000.0},
#  {'_id': 'Real Block - The first 3D Social Game on Facebook!',
#   'demande': 450000.0},
#  {'_id': 'Unique B&B by preserving historic MCM Jap. Prairie ranch',
#   'demande': 450000.0},
#  {'_id': 'ComiCosplay Cafe', 'demande': 450000.0},
#  {'_id': 'Taiga Legacy - providing exotic trees & fruits year-round',
#   'demande': 450000.0},
#  {'_id': 'Crescent Moon Spirits LLC', 'demande': 450000.0},
#  {'_id': 'No Blood...Just Diamonds...American Woodie in Sierra Leone',
#   'demande': 450000.0},
#  {'_id': 'GazillionairesLife: a new way to Buy, Sell, and Trade! (Canceled)',
#   'demande': 450000.0},
#  {'_id': 'SELF-SUSTAINING ORGANIC FARM', 'demande': 450000.0},
#  {'_id': '3D Printed windsurf, kite, surf, and paddle SmartBoardsï¿½',
#   'demande': 450000.0},
#  {'_id': 'New AviCulture System', 'demande': 450000.0},
#  {'_id': '"BERN" ï¿½ The Bernie Sanders Documentary (Canceled)',
#   'demande': 448129.0},
#  {'_id': 'iFly Hand Held Camera Crane- pan AND tilt - iPhone GoPro etc',
#   'demande': 444000.0},
#  {'_id': 'Los Angeles Laser Tag', 'demande': 435500.0},
#  {'_id': "SPLIT: The World's Only Earbuds with no Strings Attached",
#   'demande': 435000.0},
#  {'_id': 'The Dogwood Inn: A New B&B for an Old River Town!',
#   'demande': 430000.0},
#  {'_id': 'Top Side Dinner Show! Eat, watch, party, and always enjoy!',
#   'demande': 425000.0},
#  {'_id': 'A Veterans FIVE Year Mission!!!', 'demande': 425000.0},
#  {'_id': 'Salt Bill Home Beer Kit', 'demande': 425000.0},
#  {'_id': 'Gobuggs the movie', 'demande': 419666.0},
#  {'_id': 'Art, Music & Food Incorporated', 'demande': 415900.0},
#  {'_id': 'Sports Cards Unlimited (Canceled)', 'demande': 400000.0},
#  {'_id': 'NOMOREGMOFOODS', 'demande': 400000.0},
#  {'_id': 'Dangerous Seas: A Beautiful Under Water War App (Canceled)',
#   'demande': 400000.0},
#  {'_id': 'Adventure Combat Ops - A real life, apocalyptic video game!',
#   'demande': 400000.0},
#  {'_id': 'Feature Film - Friendly Ghosts - James Dean', 'demande': 400000.0},
#  {'_id': 'A-List Celebrity, Hollywood Produced LGBT Reality Series',
#   'demande': 400000.0},
#  {'_id': 'Restaurants digital menu app with language translation',
#   'demande': 400000.0},
#  {'_id': 'Higgy: Your Real Person, Travel Advisor and Agent App',
#   'demande': 400000.0},
#  {'_id': '"Arab Money" The Movie plus a Sound Track (Canceled)',
#   'demande': 400000.0},
#  {'_id': 'Hooked on a rail', 'demande': 400000.0},
#  {'_id': "Joe N'Mo To Go!", 'demande': 400000.0},
#  {'_id': 'Little Magdeline (Film)', 'demande': 400000.0},
#  {'_id': "'Street God'", 'demande': 400000.0},
#  {'_id': 'Pueblo Underground Theater (Canceled)', 'demande': 400000.0},
#  {'_id': 'Kingdom of Oberon', 'demande': 400000.0},
#  {'_id': 'Austin City Limits 40 Year History Documentary Film',
#   'demande': 400000.0},
#  {'_id': 'Blue Elephants', 'demande': 400000.0},
#  {'_id': 'M.A.C.S. (Canceled)', 'demande': 400000.0},
#  {'_id': 'LifeCool - Amazing lifesaving cooler for all boats!',
#   'demande': 400000.0},
#  {'_id': 'Pray For Dark (Canceled)', 'demande': 400000.0},
#  {'_id': 'Full feature film: Alfredo', 'demande': 400000.0},
#  {'_id': 'Project Arcane', 'demande': 400000.0},
#  {'_id': 'Power Rangers | fan film reboot movie', 'demande': 400000.0},
#  {'_id': 'How to use your voice powerfully & everyday, made easy!',
#   'demande': 400000.0},
#  {'_id': 'Crime Busters (Canceled)', 'demande': 400000.0},
#  {'_id': 'marko. Clothing Launch (Canceled)', 'demande': 400000.0},
#  {'_id': 'The Puppet Show: Season 2', 'demande': 400000.0},
#  {'_id': 'To The Death', 'demande': 400000.0},
#  {'_id': 'The Renaissance Man', 'demande': 400000.0},
#  {'_id': 'The Tymeblock Experience (Canceled)', 'demande': 400000.0},
#  {'_id': 'Health & Fitness Meal by ProteinPharm', 'demande': 400000.0},
#  {'_id': 'Three60 Beer brewing System', 'demande': 400000.0},
#  {'_id': 'Sprayview Campground: A Sustainable Rockaway Community',
#   'demande': 400000.0},
#  {'_id': 'Howling Moon Productions Film', 'demande': 400000.0},
#  {'_id': '1979 REVOLUTION: Black Friday', 'demande': 395000.0},
#  {'_id': 'project:13 - a music driven animation trilogy', 'demande': 390000.0},
#  {'_id': 'Deathfire: Ruins of Nethermore RPG', 'demande': 390000.0},
#  {'_id': 'Johnny Rocketfingers 3', 'demande': 390000.0},
#  {'_id': 'CitriSlicer - a clean, simple method to serve sliced lemons',
#   'demande': 390000.0},
#  {'_id': 'The Super Amazing Hummus Micro-Factory', 'demande': 389900.0},
#  {'_id': 'Open Source Technology Improvement Fund (OSTIF)',
#   'demande': 388000.0},
#  {'_id': 'Fighting out of Tijuana', 'demande': 385000.0},
#  {'_id': 'Fragmented Reality: New Technology and World Defense (Game)',
#   'demande': 385000.0},
#  {'_id': '"Programming in Pearls" Monument by Sabra Tull Meyer',
#   'demande': 385000.0},
#  {'_id': "Hey Chicago  It's all about you!", 'demande': 380000.0},
#  {'_id': "The Sweet Fox Fudge Open's It's Doors", 'demande': 380000.0},
#  {'_id': 'The Golf Farm', 'demande': 380000.0},
#  {'_id': 'TREE60 - Christmas Tree Stand "Rotate & Decorate"',
#   'demande': 375000.0},
#  {'_id': 'THE SESSIONS - The Beatles at Abbey Road Studios (Canceled)',
#   'demande': 375000.0},
#  {'_id': 'Black Ice - How blacks enslaved invented the game of hockey',
#   'demande': 375000.0},
#  {'_id': 'Time travel app', 'demande': 375000.0},
#  {'_id': 'Today.Feats.Us = The Human Fund', 'demande': 375000.0},
#  {'_id': 'DREAMER- Full-Length Motion Picture of a Modern-Day Joseph',
#   'demande': 375000.0},
#  {'_id': 'Thimbleweed Park: A New Classic Point & Click Adventure!',
#   'demande': 375000.0},
#  {'_id': "'Line Pirates Facebook Game", 'demande': 374484.0},
#  {'_id': "It's The GOD Complex", 'demande': 372625.0},
#  {'_id': 'ViewCoze.com | Cozy viewing from home (Canceled)',
#   'demande': 370000.0},
#  {'_id': 'RenFest Comedy TV Show (Canceled)', 'demande': 365000.0},
#  {'_id': 'Pro Tailgater Party Plate', 'demande': 365000.0},
#  {'_id': 'DEADSKINS (Canceled)', 'demande': 365000.0},
#  {'_id': 'Air Dash Online  - A Competitive Platform Fighter (Canceled)',
#   'demande': 355555.0},
#  {'_id': 'A Hard Place', 'demande': 350000.0},
#  {'_id': 'Nomasoak-The first truly portable hot tub', 'demande': 350000.0},
#  {'_id': 'The Outdoor Kid', 'demande': 350000.0},
#  {'_id': 'CHRONOLOGY', 'demande': 350000.0},
#  {'_id': 'Sculpture set to be given to Woodstock NY THE BAND set',
#   'demande': 350000.0},
#  {'_id': '*FLASHLIFE* Most Complete Emergency Survival Product Ever.',
#   'demande': 350000.0},
#  {'_id': 'Forgotten Warriors', 'demande': 350000.0},
#  {'_id': 'The Kabul Golf Club', 'demande': 350000.0},
#  {'_id': "Cats! Cafe! Let's Bring a Purrfect Combination to LA!",
#   'demande': 350000.0},
#  {'_id': "Sparkbox the World's Most Powerful Portable Power Source",
#   'demande': 350000.0},
#  {'_id': 'fixl', 'demande': 350000.0},
#  {'_id': 'Crazy Shades of Blue', 'demande': 350000.0},
#  {'_id': 'The Illuminated Messiah Bible & Art Exhibit', 'demande': 350000.0},
#  {'_id': 'Pico C - Craft Brewing For All', 'demande': 350000.0},
#  {'_id': 'BassCase - Bold Sound in an iPhone Case', 'demande': 350000.0},
#  {'_id': 'hopps | patrons order drinks, venues drive revenue',
#   'demande': 350000.0},
#  {'_id': 'Recrudescence Online (Canceled)', 'demande': 350000.0},
#  {'_id': 'Pepe & Lucas: The Animated Series', 'demande': 350000.0},
#  {'_id': 'Dr. Mï¿½s Universeï¿½ featuring Jerry Lucas, a.k.a. Dr. Memoryï¿½',
#   'demande': 350000.0},
#  {'_id': 'People Who Inspire Us', 'demande': 350000.0},
#  {'_id': 'The American Big Pharma Film', 'demande': 350000.0},
#  {'_id': 'Creating an online game, "Perdition Online".', 'demande': 350000.0},
#  {'_id': 'PlayToLearn.com', 'demande': 350000.0},
#  {'_id': 'The Blue Vale: A Tabletop RPG in Augmented Reality',
#   'demande': 350000.0},
#  {'_id': 'Blackspace - Plan. Dig. Defend. Survive.', 'demande': 350000.0},
#  {'_id': 'Chad Hart is Not So Vain - Straight V Gay makeover',
#   'demande': 350000.0},
#  {'_id': 'AppEater - Your Mobile desktop will never be safe again!',
#   'demande': 350000.0},
#  {'_id': 'King James Version Bible comic book', 'demande': 350000.0},
#  {'_id': 'PALOMINAS', 'demande': 350000.0},
#  {'_id': 'Hey Moe! Hey Dad!', 'demande': 350000.0},
#  {'_id': 'SLAYING GIANTS #GOLIATH', 'demande': 350000.0},
#  {'_id': 'Velvet Blu Mediterranean Restaurant', 'demande': 350000.0},
#  {'_id': '"Snap Cover" for an Electrical outlet', 'demande': 350000.0},
#  {'_id': 'Lets Build/Buy a house (Canceled)', 'demande': 350000.0},
#  {'_id': 'CODE OF DEATH (Canceled)', 'demande': 350000.0},
#  {'_id': 'Have a dish named after you', 'demande': 350000.0},
#  {'_id': 'Art Story', 'demande': 350000.0},
#  {'_id': 'Choices', 'demande': 350000.0},
#  {'_id': 'RANCH GIRLS', 'demande': 350000.0},
#  {'_id': 'Katun', 'demande': 350000.0},
#  {'_id': 'Help Archie Comics Build a New Riverdale (Canceled)',
#   'demande': 350000.0},
#  {'_id': 'Help us create Possession The Old Story movie like no other!',
#   'demande': 350000.0},
#  {'_id': 'Never Forgotten Project', 'demande': 350000.0},
#  {'_id': 'Spoils of War (TM)', 'demande': 350000.0},
#  {'_id': 'Patented MoveNetic Lock - New Post 9-11 Locking Method',
#   'demande': 350000.0},
#  {'_id': 'CRE81 RIDESHARE APP', 'demande': 350000.0},
#  {'_id': 'Second Sunrise Movie Project', 'demande': 350000.0},
#  {'_id': 'Social Media Impact of Student Violence', 'demande': 350000.0},
#  {'_id': 'StarDrive Propulsion (Canceled)', 'demande': 350000.0},
#  {'_id': 'The Alone (Canceled)', 'demande': 350000.0},
#  {'_id': "Timothy Zahn's Parallax (turn-based 4X galactic conquest)",
#   'demande': 350000.0},
#  {'_id': 'Protection bag to carry equipment with lithium batteries.',
#   'demande': 350000.0},
#  {'_id': '"FRIGHT PLAN"', 'demande': 345000.0},
#  {'_id': 'Gemini - The Album that Changed The World (Canceled)',
#   'demande': 340320.0},
#  {'_id': 'War At Home', 'demande': 340000.0},
#  {'_id': 'VEGETABLE UPRISING URBAN ROOFTOP FARM (Canceled)',
#   'demande': 336000.0},
#  {'_id': 'Sinners Holiday', 'demande': 333000.0},
#  {'_id': '"I SAVE LIVES" The App To Protect Aircraft From Small Drones',
#   'demande': 330000.0},
#  {'_id': 'Hairbands, Pilot Episode', 'demande': 325000.0},
#  {'_id': 'Crankers, Tweeners & Strokers (Canceled)', 'demande': 325000.0},
#  {'_id': 'G1: Innovative Dental Design', 'demande': 325000.0},
#  {'_id': 'Save the Circus', 'demande': 325000.0},
#  {'_id': 'Ceramic Pie Studios', 'demande': 325000.0},
#  {'_id': 'Hydro Electrical stand-alone generator complex.',
#   'demande': 325000.0},
#  {'_id': 'The Gamers: Hands of Fate', 'demande': 320000.0},
#  {'_id': 'Adam 2.0   From Young Man to Real Man', 'demande': 320000.0},
#  {'_id': 'Ninja Zombies! (Canceled)', 'demande': 315000.0},
#  {'_id': 'Design the Starship Enterprise Science Research Mock Up',
#   'demande': 313550.0},
#  {'_id': 'Throwing an art event In Petersburg VA', 'demande': 313400.0},
#  {'_id': 'The Nut Hut', 'demande': 305365.0},
#  {'_id': 'WhosRunningAnyway', 'demande': 305000.0},
#  {'_id': 'SURVIVING TRUMP Diverse People Making America Great Everyday',
#   'demande': 300000.0},
#  {'_id': 'Twilight Nation', 'demande': 300000.0},
#  {'_id': 'Pink me! Bakery (Canceled)', 'demande': 300000.0},
#  {'_id': 'Local Area Drone Dispatch and Authorization System (LADDAS)',
#   'demande': 300000.0},
#  {'_id': 'Kvits - Technology that Improves Dining', 'demande': 300000.0},
#  {'_id': 'Black Duct - An innovation in heating and cooling systems.',
#   'demande': 300000.0},
#  {'_id': 'PA Golf American Red Carpet Launch Project/Event',
#   'demande': 300000.0},
#  {'_id': 'Data Stocks\'s "Money Machine" Mobile Application',
#   'demande': 300000.0},
#  {'_id': '50 Shades of Silver Hair and Socks', 'demande': 300000.0},
#  {'_id': 'Not only a Bluetooth Amplifier. Its so much more and compact',
#   'demande': 300000.0},
#  {'_id': 'Farming the better red meat', 'demande': 300000.0},
#  {'_id': 'Shin Do Kumat? - Return of Ancient Ones', 'demande': 300000.0},
#  {'_id': 'Experiencing the Divine Comedy', 'demande': 300000.0},
#  {'_id': 'Ryan\'s art studio $1 for printable 16"/20"', 'demande': 300000.0},
#  {'_id': 'Minis with Enemies, taking tabletop mini gaming digital!',
#   'demande': 300000.0},
#  {'_id': 'aid path (Canceled)', 'demande': 300000.0},
#  {'_id': 'ThumbDancer', 'demande': 300000.0},
#  {'_id': 'MindStream Aquarium Monitor', 'demande': 300000.0},
#  {'_id': 'Citana: Animation Streaming', 'demande': 300000.0},
#  {'_id': 'Meet kubo: an electric scooter to carry all your stuff!',
#   'demande': 300000.0},
#  {'_id': 'Vluxe: Fashion Like No Other On Earth.', 'demande': 300000.0},
#  {'_id': 'Life Online', 'demande': 300000.0},
#  {'_id': 'Space Trucker', 'demande': 300000.0},
#  {'_id': 'Shadow Black Gaming & Community Center (Canceled)',
#   'demande': 300000.0},
#  {'_id': 'Samurai Lone Wolf', 'demande': 300000.0},
#  {'_id': 'Shine On New World', 'demande': 300000.0},
#  {'_id': 'Aviation Brewing Company', 'demande': 300000.0},
#  {'_id': 'We want your money (Suspended)', 'demande': 300000.0},
#  {'_id': 'Equestrian Complex & Western Museum (Canceled)',
#   'demande': 300000.0},
#  {'_id': 'Triple Espresso Goes to The Big Apple', 'demande': 300000.0},
#  {'_id': 'Sheep Dogs', 'demande': 300000.0},
#  {'_id': 'HOPE! Making fantasy a reality....', 'demande': 300000.0},
#  {'_id': 'Chips Challenge Ultimate 3D', 'demande': 300000.0},
#  {'_id': 'Skyteboard 3G Quadcopter with Fatdoor Social Network Connect',
#   'demande': 300000.0},
#  {'_id': 'BRIDEGROOM - An American Love Story', 'demande': 300000.0},
#  {'_id': 'Literary Animated Mobile Book Application', 'demande': 300000.0},
#  {'_id': 'Baja ATV Park (Suspended)', 'demande': 300000.0},
#  {'_id': 'The BeltFctry', 'demande': 300000.0},
#  {'_id': 'The Blur', 'demande': 300000.0},
#  {'_id': 'Warehouse 34 (Canceled)', 'demande': 300000.0},
#  {'_id': 'Electric Vehicle Self Charging system - Drive and Charge',
#   'demande': 300000.0},
#  {'_id': 'The Untitled Highly Inappropriate Project', 'demande': 300000.0},
#  {'_id': 'Oreggio.com', 'demande': 300000.0},
#  {'_id': 'Comedy Spoof Yucca Man movie (Canceled)', 'demande': 300000.0},
#  {'_id': 'Mass Produce', 'demande': 300000.0},
#  {'_id': '"Songs from the 21st century"  - new rock 4 a new world',
#   'demande': 300000.0},
#  {'_id': 'OFA Opening Night', 'demande': 300000.0},
#  {'_id': 'Bee Barrels: The 21st Century Beehive!', 'demande': 300000.0},
#  {'_id': 'Animated Short Series- Spookiz', 'demande': 300000.0},
#  {'_id': "Shipper's Market", 'demande': 300000.0},
#  {'_id': 'The Cones of Dunshire (Canceled)', 'demande': 300000.0},
#  {'_id': 'A Place to Gather Writing Center, LLC', 'demande': 300000.0},
#  {'_id': 'All Points Bulletin (APB): Vendetta', 'demande': 300000.0},
#  {'_id': 'Nhuad Single Hand Video Game Controllers', 'demande': 300000.0},
#  {'_id': 'Dungeonforge', 'demande': 300000.0},
#  {'_id': 'CREATURES OF THE NIGHT (Canceled)', 'demande': 300000.0},
#  {'_id': 'Godless Artist', 'demande': 300000.0},
#  {'_id': 'Karma Plus: The Socially Conscious Network & Kindness App',
#   'demande': 300000.0},
#  {'_id': "New Year's Gala for unveiling of Historic Opera Relic",
#   'demande': 300000.0},
#  {'_id': 'The Great Pyramid, Project USA', 'demande': 300000.0},
#  {'_id': 'Recording Studio', 'demande': 300000.0},
#  {'_id': 'Kicked Out!', 'demande': 300000.0},
# ...
#   'demande': 273000.0},
#  {'_id': 'illo - birth of the cool (Canceled)', 'demande': 270000.0},
#  {'_id': 'Salad Barr ( the new fast food restaurant )', 'demande': 270000.0},
#  {'_id': 'Otaku Kingyo Seiiki (Canceled)', 'demande': 270000.0},
#  {'_id': 'Lamp | The Ultimate Adjustable Stand+Dock+LED Light',
#   'demande': 270000.0},
#  {'_id': 'Supercar Garageï¿½ TV', 'demande': 265000.0},
#  {'_id': 'Janus World Summit & Festival: recognizing talent worldwide',
#   'demande': 265000.0},
#  {'_id': 'Burlington Waterworks: Banquet, Museum and Community Center',
#   'demande': 264698.0},
#  {'_id': 'Lightpack ï¿½ ambient backlight for your displays',
#   'demande': 261962.0},
#  {'_id': 'The Dash ï¿½ Wireless Smart In Ear Headphones', 'demande': 260000.0},
#  {'_id': 'Swimming With Guppies', 'demande': 260000.0},
#  {'_id': 'THE GREAT CANADIAN TAR SANDS SWINDLE', 'demande': 260000.0},
#  {'_id': 'ParaShoot - Smart HD Videography Everyone Can Wear',
#   'demande': 260000.0},
#  {'_id': 'Saving Capitalism - Starring Robert Reich', 'demande': 256500.0},
#  {'_id': 'HERO[3] Web Filter Suite - A New Way to Protect Your Family',
#   'demande': 250000.0},
#  {'_id': 'Hubo - Extension Box for iPhone', 'demande': 250000.0},
#  {'_id': 'DREAD: Book of Lovecraft', 'demande': 250000.0},
#  {'_id': 'Calypso Music Festival', 'demande': 250000.0},
#  {'_id': 'Morrison Land', 'demande': 250000.0},
#  {'_id': 'Cape Cinema', 'demande': 250000.0},
#  {'_id': "Small Change: Kids' Financial Life Skills", 'demande': 250000.0},
#  {'_id': 'The Bucket Booster!', 'demande': 250000.0},
#  {'_id': 'Soriba or Goods Doer', 'demande': 250000.0},
#  {'_id': 'Dark Meridian', 'demande': 250000.0},
#  {'_id': 'FLOW: Life Unplugged-High Definition Bluetooth +APTX Adapter',
#   'demande': 250000.0},
#  {'_id': 'Cocktail Sideshow Bar', 'demande': 250000.0},
#  {'_id': 'The Game Room', 'demande': 250000.0},
#  {'_id': 'Bosses Affiliated sneaker and clothing line', 'demande': 250000.0},
#  {'_id': 'JOHN SKIPP\'S "ROSE": THE 3D ZOMBIE PUPPET MUSICAL!',
#   'demande': 250000.0},
#  {'_id': 'Abduction alert bracelets', 'demande': 250000.0},
#  {'_id': 'Ghostbusters: The Board Game II', 'demande': 250000.0},
#  {'_id': 'Print-a-Part3d.com', 'demande': 250000.0},
#  {'_id': 'Aladdin Lucid Dreaming Stimulator', 'demande': 250000.0},
#  {'_id': '"FIRST DOG: SECOND TERM"', 'demande': 250000.0},
#  {'_id': 'The Ugly Mexican (Canceled)', 'demande': 250000.0},
#  {'_id': 'Seeds of Our Future Farms', 'demande': 250000.0},
#  {'_id': 'Zig', 'demande': 250000.0},
#  {'_id': 'Historic B&B with an in-house French Bakery in Memphis, TN',
#   'demande': 250000.0},
#  {'_id': 'Diabetic Simple', 'demande': 250000.0},
#  {'_id': 'Gocycle - the BEST folding electric bike in the world!',
#   'demande': 250000.0},
#  {'_id': 'UPCYCREATION for a Clearer Future', 'demande': 250000.0},
#  {'_id': 'Mother Earth Needs Our Help', 'demande': 250000.0},
#  {'_id': 'HelSTAR: The Wireless Helmet Brake & Signal Light',
#   'demande': 250000.0},
#  {'_id': 'Mariner Farms: local, closed loop, organic food production.',
#   'demande': 250000.0},
#  {'_id': 'WOODSHOP', 'demande': 250000.0},
#  {'_id': 'Purchase B.o.B A Ticket To Space On A Virgin Galactic Flight',
#   'demande': 250000.0},
#  {'_id': "Mist' R Bucket (Canceled)", 'demande': 250000.0},
#  {'_id': 'Hemingwrite - A Distraction Free Digital Typewriter',
#   'demande': 250000.0},
#  {'_id': 'Terahex 1000 Bot (Hexacopter/Multirotor/Drone) (Canceled)',
#   'demande': 250000.0},
#  {'_id': 'Storybricks, the storytelling online RPG', 'demande': 250000.0},
#  {'_id': 'Copy2', 'demande': 250000.0},
#  {'_id': 'The Guilt Free Life', 'demande': 250000.0},
#  {'_id': 'A Caribbean Internet Radio Station operating like "NPR"',
#   'demande': 250000.0},
#  {'_id': 'DIG COMICS', 'demande': 250000.0},
#  {'_id': 'GreenResolve Home Energy Monitor', 'demande': 250000.0},
#  {'_id': 'The Den Alternative Center', 'demande': 250000.0},
#  {'_id': 'Trump Redux: Help us tell the real story about Donald Trump.',
#   'demande': 250000.0},
#  {'_id': 'Percussion Archive', 'demande': 250000.0},
#  {'_id': 'Core Activation Training System for Better Physical Movement',
#   'demande': 250000.0},
#  {'_id': 'GIVING', 'demande': 250000.0},
#  {'_id': 'Beautify our Highways', 'demande': 250000.0},
#  {'_id': 'We, the Enslaved', 'demande': 250000.0},
#  {'_id': 'MowBuddy', 'demande': 250000.0},
#  {'_id': 'The Chivalrous Society on the Cutting Edge of Normal ï¿½?',
#   'demande': 250000.0},
#  {'_id': 'Sweet Apple Pie Fries!', 'demande': 250000.0},
#  {'_id': 'iTworx', 'demande': 250000.0},
#  {'_id': '"SUDS COUNTY 2: The Boil Over" A San Diego Beer Documentary',
#   'demande': 250000.0},
#  {'_id': "Masters of the Kingdomï¿½Don't just visit Disneyland, play it!",
#   'demande': 250000.0},
#  {'_id': '21st CENTURY MEDICAL PRACTICE SYSTEM THAT CHANGES THE WORLD',
#   'demande': 250000.0},
#  {'_id': 'Saints of The Classroom', 'demande': 250000.0},
#  {'_id': 'The Essence Within Game Project', 'demande': 250000.0},
#  {'_id': 'King of the Dead - A Horror / Comedy Movie', 'demande': 250000.0},
#  {'_id': 'MaxMyTV: Home Automation and Social Media Overlay on your TV',
#   'demande': 250000.0},
#  {'_id': 'Vanishing Culture (Canceled)', 'demande': 250000.0},
#  {'_id': 'Black On Black Murder in America! Stoping This Madness!',
#   'demande': 250000.0},
#  {'_id': 'The Book of Self Help: Depression Quest', 'demande': 250000.0},
#  {'_id': 'Breathe Easy Infusion Chapmint (Canceled)', 'demande': 250000.0},
#  {'_id': 'jfg76tukv u', 'demande': 250000.0},
#  {'_id': 'The Barette Kaddy, Colorful, Rotating Storage Unit',
#   'demande': 250000.0},
#  {'_id': 'Music Has Legs movie', 'demande': 250000.0},
#  {'_id': 'Organic, tasty Shrimps from Northern Germany into the world',
#   'demande': 250000.0},
#  {'_id': 'Revolutionary Music, Arts & Technology Festival (w/ Book)',
#   'demande': 250000.0},
#  {'_id': 'LEGEND OF A HITMAN (Canceled)', 'demande': 250000.0},
#  {'_id': 'Moonlight 5 star (Canceled)', 'demande': 250000.0},
#  {'_id': 'Lit Savage Wrestling', 'demande': 250000.0},
#  {'_id': "Iota: Never lose sight of what's important.", 'demande': 250000.0},
#  {'_id': '"Madam Mississippi"', 'demande': 250000.0},
#  {'_id': 'The Launch Jacket', 'demande': 250000.0},
#  {'_id': 'Sit and Be Fit - Keep The Dream Alive (Canceled)',
#   'demande': 250000.0},
#  {'_id': 'The Chronicles Of The Green Mile Club', 'demande': 250000.0},
#  {'_id': 'Penny Arcade Sells Out', 'demande': 250000.0},
#  {'_id': 'Sky Bridge: Fallen Stars', 'demande': 250000.0},
#  {'_id': 'My little Big Data - Your 1st True Personal Home Server',
#   'demande': 250000.0},
#  {'_id': 'Pathologic (???.??????)', 'demande': 250000.0},
#  {'_id': 'The Dick Jones Feature Film Project', 'demande': 250000.0},
#  {'_id': 'Voxpop', 'demande': 250000.0},
#  {'_id': 'Unfinished Business:  A Ghost Story', 'demande': 250000.0},
#  {'_id': 'WOW Education Rewards - Furry Witty Edufeed Reward',
#   'demande': 250000.0},
#  {'_id': 'Myythic: The Buried Temple of Alimar (Canceled)',
#   'demande': 250000.0},
#  {'_id': 'So-Gnar Sounds stereo infused lifejacket and sports apparel',
#   'demande': 250000.0},
#  {'_id': 'Metro County PD', 'demande': 250000.0},
#  {'_id': 'PARTYGRAM', 'demande': 250000.0},
#  {'_id': 'Miracle Mouse-Cranky\'s Miracle, 2D "Throw-Back" Feature Film',
#   'demande': 250000.0},
#  {'_id': 'Operation Rock Bottom - The Power of Wall St. on Your St',
#   'demande': 250000.0},
#  {'_id': 'Bakery/Cafe', 'demande': 250000.0},
#  {'_id': 'Uncommon Wealth', 'demande': 250000.0},
#  {'_id': 'Supercar Garageï¿½:  Stage One', 'demande': 250000.0},
#  {'_id': 'Chronicles - History by us, as we tell it, as we share it',
#   'demande': 250000.0},
#  {'_id': 'Clean2Clear', 'demande': 250000.0},
#  {'_id': 'Soaring Beyond - A 90 Day Empowering Life Transformation',
#   'demande': 250000.0},
#  {'_id': 'Beyond the Pillowed Bed', 'demande': 250000.0},
#  {'_id': 'Mega Project: A FUTURE Without Chemicals and Healthy Food.',
#   'demande': 250000.0},
#  {'_id': 'The Visual Bible Experience - Watch The Bible Come To Life!',
#   'demande': 250000.0},
#  {'_id': 'WETGEAR "RIPFLIP" The World\'s First Walkable Flipper!',
#   'demande': 250000.0},
#  {'_id': "Flynn's Pizza", 'demande': 250000.0},
#  {'_id': 'KaliPAK is a portable, renewable energy generator',
#   'demande': 250000.0},
#  {'_id': 'CANDY MOUNTAIN', 'demande': 250000.0},
#  {'_id': 'All Race Matters! (Canceled)', 'demande': 250000.0},
#  {'_id': 'F-35 Lightning II, Modern Combat Sim: Single Player and MMOG',
#   'demande': 250000.0},
#  {'_id': "World's First Custom Fit Sandals, 3D Printed in USA",
#   'demande': 250000.0},
#  {'_id': "World's Greatest Card Tricks Ever Revealed", 'demande': 250000.0},
#  {'_id': 'Zippy Pop! The Ultimate Stove top Snack Maker!',
#   'demande': 250000.0},
#  {'_id': 'Independent By Choice - Advocating A New Political Model',
#   'demande': 250000.0},
#  {'_id': 'The Poopy Pals First Adventure', 'demande': 250000.0},
#  {'_id': 'Project Patriotic Eats: Food Channel & Food Truck . GO USA!!',
#   'demande': 250000.0},
#  {'_id': 'The Legend of the Lost Rose by Pazzaria Productions',
#   'demande': 250000.0},
#  {'_id': 'Fitness App that does it all. Kilojoules', 'demande': 250000.0},
#  {'_id': "World's 1st,,Finest ARTISAN Crafted water waits for you.",
#   'demande': 250000.0},
#  {'_id': 'Laser Headphones (Canceled)', 'demande': 250000.0},
#  {'_id': 'Jayhawk Racing Bikes', 'demande': 250000.0},
#  {'_id': 'Interactive Smart Tables', 'demande': 250000.0},
#  {'_id': 'Invergo: An Automated Pour Over Coffee System', 'demande': 250000.0},
#  {'_id': 'high school football focus', 'demande': 250000.0},
#  {'_id': '2 Brothers Woodfired Deli and Pizzeria', 'demande': 250000.0},
#  {'_id': 'DNA: Code Flesh (Book One: Dead Nations Army Duology)',
#   'demande': 250000.0},
#  {'_id': 'The Arts of Performing', 'demande': 250000.0},
#  {'_id': 'SousVide Supreme Touch+', 'demande': 250000.0},
#  {'_id': 'STEM System: The Best Way to Interact with Virtual Worlds',
#   'demande': 250000.0},
#  {'_id': "Ron Maxwell's Civil War Classics (Canceled)", 'demande': 250000.0},
#  {'_id': 'The Historical Hall of Fame (Canceled)', 'demande': 250000.0},
#  {'_id': 'Ariel Sky - The Future of Healthcare', 'demande': 250000.0},
#  {'_id': 'MOST. BLOOD. EVER.', 'demande': 250000.0},
#  {'_id': 'Pollution Fighting, with Lawnmower Lighting! Cooler Mowing.',
#   'demande': 250000.0},
#  {'_id': 'The REAL Trump University - The Art of the STEAL',
#   'demande': 250000.0},
#  {'_id': 'The Russian Sharks', 'demande': 250000.0},
#  {'_id': 'ZICAM: THE UNTOLD STORY', 'demande': 250000.0},
#  {'_id': 'Nastaran (Wild Rose)', 'demande': 250000.0},
#  {'_id': 'Dancing Dragon', 'demande': 250000.0},
#  {'_id': 'Android Device Monitoring - Catch Me If You Can',
#   'demande': 250000.0},
#  {'_id': 'The Fuffr Touch Case ï¿½ Multitouch Outside Your Smartphone',
#   'demande': 250000.0},
#  {'_id': "Studio Lot 13's The Scream Scene Theater", 'demande': 250000.0},
#  {'_id': 'Take And Seek the Movie', 'demande': 250000.0},
#  {'_id': 'JOIN THE MOVEMENT TO GROW MORSO (Canceled)', 'demande': 250000.0},
#  {'_id': 'Zurvive! A Live Action Survival Horror Game', 'demande': 250000.0},
#  {'_id': 'DrYvr- A feature length horror/thriller film', 'demande': 250000.0},
#  {'_id': 'Kurt Vonnegut: Unstuck in Time', 'demande': 250000.0},
#  {'_id': "sonoro Cubo: World's First All-In-One SmartHome Audio System",
#   'demande': 250000.0},
#  {'_id': 'BIP Records, support the movement and it will support you.',
#   'demande': 250000.0},
#  {'_id': 'Remix IO - A 4K, Nougat-powered, All-in-One device',
#   'demande': 250000.0},
#  {'_id': 'Fast Easy Lightweight Modular Cabinets PhastPhurniture',
#   'demande': 250000.0},
#  {'_id': 'THE ESSENCE OF BACON', 'demande': 250000.0},
#  {'_id': 'Two Sides for a Mirror', 'demande': 250000.0},
#  {'_id': 'Evoljeans-Iwear Company', 'demande': 250000.0},
#  {'_id': 'THE GREAT COMET - An Independent Film', 'demande': 250000.0},
#  {'_id': 'The Undersea Aviary', 'demande': 250000.0},
#  {'_id': 'The Luscious Palace', 'demande': 250000.0},
#  {'_id': 'The BEST WATER EVER 7.8 PH Highest all Natural water.',
#   'demande': 250000.0},
#  {'_id': "Bogart Bay Shrimp - Missouri's First Salt Water Shrimp Farm",
#   'demande': 250000.0},
#  {'_id': 'Vir-Sec, SecureCommunique with SecureAxcess. Cyber Security',
#   'demande': 250000.0},
#  {'_id': 'Localvotion: Connecting farms to LOCAVORES', 'demande': 250000.0},
#  {'_id': 'Meeting Mapper', 'demande': 250000.0},
#  {'_id': 'Introducing the Airdog ADII: The Future is Hands-Free',
#   'demande': 250000.0},
#  {'_id': "D.A.'s dresses, ties, bow ties, blankets, gifts, and cakes!",
#   'demande': 250000.0},
#  {'_id': 'Wheeliesï¿½ Revolutionary Display For Your Motorcycle',
#   'demande': 250000.0},
#  {'_id': 'MindGear - Mind Control for Your iPhone or Android Phone',
#   'demande': 250000.0},
#  {'_id': 'The Cyanide & Happiness Show', 'demande': 250000.0},
#  {'_id': 'The Blue Eagle California Times Shoppers Bargain Guide',
#   'demande': 250000.0},
#  {'_id': 'North East', 'demande': 250000.0},
#  {'_id': '/r/frontpagefilms', 'demande': 250000.0},
#  {'_id': 'The Maryanne Godboldo Story (Canceled)', 'demande': 250000.0},
#  {'_id': 'Z-Magics: Magic Exposed', 'demande': 250000.0},
#  {'_id': 'Junior CMS: the scaffolding to rebuild the web a better way.',
#   'demande': 250000.0},
#  {'_id': 'A SWEET BAKERY WITH A VIEW', 'demande': 250000.0},
#  {'_id': 'CasaPlutonia Retreat: The Journey of Mind, Body, and Soul',
#   'demande': 250000.0},
#  {'_id': 'Save Movie Madness', 'demande': 250000.0},
#  {'_id': 'The War On Truth - Documentary', 'demande': 250000.0},
#  {'_id': 'The "Get Home Now" Device', 'demande': 250000.0},
#  {'_id': 'Project DaVinci - Get Access to Space', 'demande': 250000.0},
#  {'_id': '"The Wrecking Crew" The Untold Story of Rock & Roll Heroes',
#   'demande': 250000.0},
#  {'_id': "You could own my face...and why wouldn't you want that?",
#   'demande': 250000.0},
#  {'_id': 'Superior Motors: Community Restaurant & Farm Ecosystem',
#   'demande': 250000.0},
#  {'_id': 'The SEED Project', 'demande': 250000.0},
#  {'_id': 'YogaMeDo - Nutrition and Mental Health Education for Schools',
#   'demande': 250000.0},
#  {'_id': 'CellVenom - Non Lethal Personal Defense for iPhone 6/6S/7',
#   'demande': 250000.0},
#  {'_id': 'Xeko', 'demande': 250000.0},
#  {'_id': 'Jump Start Racing (Canceled)', 'demande': 250000.0},
#  {'_id': 'VET Tv - Streaming TV network for post 9/11 veterans',
#   'demande': 250000.0},
#  {'_id': 'LifeBox is a global humanitarian effort solving world hunger',
#   'demande': 250000.0},
#  {'_id': 'The Spin Wrench Worlds First Stress Free Tool! (Canceled)',
#   'demande': 250000.0},
#  {'_id': 'Complete Snake River Treehouse Pizza and Grill',
#   'demande': 250000.0},
#  {'_id': 'Louisiana Cr?ole restaurant in the heart of Miami Beach',
#   'demande': 250000.0},
#  {'_id': 'Crooked City', 'demande': 249000.0},
#  {'_id': 'Karmic Kyoto', 'demande': 249000.0},
#  {'_id': "Tony La Russa's Baseball with Fans", 'demande': 249000.0},
#  {'_id': 'Time Lapse U.S.', 'demande': 247000.0},
#  {'_id': 'Z-Style Concept Arm', 'demande': 240000.0},
#  {'_id': '"8 Songs" Documentary - Did music shape human evolution?',
#   'demande': 240000.0},
#  {'_id': 'Shaolin Time Master/Back To Urantia', 'demande': 237000.0},
#  {'_id': 'The First Iditarod: The Amazing Dogs & Their Mushers',
#   'demande': 235000.0},
#  {'_id': "Zombie Mike now that he's dead he's really living",
#   'demande': 235000.0},
#  {'_id': 'RoboTar Guitar Chord Robot helps you Play Guitar! (Canceled)',
#   'demande': 230000.0},
#  {'_id': 'Galactic Raiders feature-Kickstarter', 'demande': 229200.0},
#  {'_id': '4ARMS', 'demande': 227000.0},
#  {'_id': '[Project: Monolith]', 'demande': 225000.0},
#  {'_id': 'Suburban Invasion: The Ultimate Off-Road Experience',
#   'demande': 225000.0},
#  {'_id': 'MONSTER FEST (Canceled)', 'demande': 225000.0},
#  {'_id': 'Oculus Maximus (Canceled)', 'demande': 225000.0},
#  {'_id': 'INFLUENCERS ACADEMY 2016', 'demande': 225000.0},
#  {'_id': "John Knight's Operation: Project A.L.B.A (Canceled)",
#   'demande': 225000.0},
#  {'_id': 'gaincontrol/guncontrol', 'demande': 225000.0},
#  {'_id': "TANKY: World's Fastest Production Drone", 'demande': 225000.0},
#  {'_id': '"Another Network" Film Project', 'demande': 225000.0},
#  ...]

# %% [markdown]
# ## Question 6

# %%
sport = collection.find({"name": {"$regex" : ".*Sport.*"}})

# %%
compteur2=0
for document in sport :
    compteur2+=1
print(compteur2)
# Out:
# 323
